# %%
import pandas as pd

# %%
dataframe = pd.read_excel('DesignationsOfficialTitles.xlsx', sheet_name = "Sheet1")

# %%
dataframe.head()
# Out:
#                          English                        Tamil  \
# 0                  Able  Seaman          …  திறமையுள்ள கடலோடி
# 1              Accident  Officer      … விபத்து உத்தியோகத்தர்
# 2  Account and Payment Division   … கணக்கு,கொடுப்பனவுப் பகுதி
# 3                     Accountant                  … கணக்காளர்
# 4           Accountant (Costing)       … கணக்காளர் (ஆகுசெலவு)
#
#                  Sinhala Unnamed: 3
# 0           දක්ෂ  නැවියා        NaN
# 1         අනතුරැ නිලධාරි        NaN
# 2  ගිණුම් සහ ගෙවීම් අංශය        NaN
# 3             ගණකාධිකාරි        NaN
# 4   ගණකාධිකාරි (මිල කරන)        NaN

# %%
dataframe.head(50)
# Out:
#                                               English  \
# 0                                       Able  Seaman
# 1                                   Accident  Officer
# 2                       Account and Payment Division
# 3                                          Accountant
# 4                                Accountant (Costing)
# 5                                   Accountancy Board
# 6                                Accountants' Service
# 7                                   Accounting Branch
# 8                         Accounting Machine Operator
# 9                                  Accounting Officer
# 10                                    Accounting Unit
# 11                                 Accounts Assistant
# 12                                    Accounts Branch
# 13                                     Accounts Clerk
# 14                                  Accounts Division
# 15                                    Accounts Office
# ...

# %%
dataframe.dropna(subset=['English', 'Tamil', 'Sinhala'], inplace = True)

# %%
dataframe.head(50)
# Out:
#                                               English  \
# 0                                       Able  Seaman
# 1                                   Accident  Officer
# 2                       Account and Payment Division
# 3                                          Accountant
# 4                                Accountant (Costing)
# 5                                   Accountancy Board
# 6                                Accountants' Service
# 7                                   Accounting Branch
# 8                         Accounting Machine Operator
# 9                                  Accounting Officer
# 10                                    Accounting Unit
# 11                                 Accounts Assistant
# 12                                    Accounts Branch
# 13                                     Accounts Clerk
# 14                                  Accounts Division
# 15                                    Accounts Office
# ...

# %%
dataframe.to_excel("DesignationsOfficialTitles.xlsx", sheet_name='Sheet1')
