# %%
import pandas as pd

# %%
df = pd.read_excel("../Corpus/Morpologies/Dataset for MAnalyzer/Person Names Si-Ta.xlsx")

# %%
dataFrame = df.head(1000)

# %%
dataFrame.dropna(subset=['Sinhala'], inplace=True)
dataFrame.dropna(subset=['Tamil'], inplace=True)
# Out:
# /Users/wimukthirajapaksha/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/wimukthirajapaksha/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#df.head()

# %%
def addMorpologyTamil(rootNamedEntity, tag):
    namedEntity = ''
    if(tag==1):     #################  ගේ
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'யின்'
        else:
            namedEntity = rootNamedEntity[:-1] + 'ின்' 
    elif(tag==2):     #################  ගෙන්
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'யில்'
        else:
            namedEntity = rootNamedEntity[:-1] + 'ில்' 
    elif(tag==3):     #################  සිට
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'யிலிருந்து'
        else:
            namedEntity = rootNamedEntity[:-1] + 'ிலிருந்து' 
    elif(tag==4):     #################  ගේ
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'யினது'
        elif(rootNamedEntity[-1] == 'ா'):
            namedEntity = rootNamedEntity[:-1] + 'வினது'
        else:
            namedEntity = rootNamedEntity + 'து'
    elif(tag==5):     #################  ළග
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'யிடம்'
        else:
            namedEntity = rootNamedEntity[:-1] + 'விடம்' 
    elif(tag==6):     #################  !
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'யே'
        else:
            namedEntity = rootNamedEntity[:-1] + 'ே' 
    elif(tag==7):     #################  ද!
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'யோ'
        else:
            namedEntity = rootNamedEntity[:-1] + 'ோ' 
    elif(tag==8):     #################  විසින්
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'யால்'
        else:
            namedEntity = rootNamedEntity[:-1] + 'ால்' 
    elif(tag==9):     #################  සමග
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'யுடன்'
        else:
            namedEntity = rootNamedEntity[:-1] + 'ுடன்' 
    elif(tag==10):     #################  සමග
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'யோடு'
        else:
            namedEntity = rootNamedEntity[:-1] + 'ோடு' 
    elif(tag==11):     #################  ව
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'யை'
        else:
            namedEntity = rootNamedEntity[:-1] + 'ை'
    elif(tag==12):     #################  ට
        if(rootNamedEntity[-1]=='ி' or rootNamedEntity[-1]=='ை'):
            namedEntity = rootNamedEntity + 'க்கு'
        else:
            namedEntity = rootNamedEntity[:-1] + 'ுக்கு'
    elif(tag==20):     #################  
        namedEntity = rootNamedEntity 
 #   else:
  #      namedEntity = rootNamedEntity
    return namedEntity

# %%
def addMorpologySinhala(rootNamedEntity, tag):
    namedEntity = ''
    if(tag==1):
        namedEntity = rootNamedEntity + 'ගේ'
    elif(tag==2):
        namedEntity = rootNamedEntity + 'ගෙන්'
    elif(tag==3):
        namedEntity = rootNamedEntity + ' සිට'
    elif(tag==4):
        namedEntity = rootNamedEntity + 'ගේ'
    elif(tag==5):
        namedEntity = rootNamedEntity + ' ළග'
    elif(tag==6):
        namedEntity = rootNamedEntity + '!'
    elif(tag==7):
        namedEntity = rootNamedEntity + ' ද!'
    elif(tag==8):
        namedEntity = rootNamedEntity + ' විසින්'
    elif(tag==9):
        namedEntity = rootNamedEntity + ' සමග'
    elif(tag==10):
        namedEntity = rootNamedEntity + 'සමග'
    elif(tag==11):
        namedEntity = rootNamedEntity + 'ව'
    elif(tag==12):
        namedEntity = rootNamedEntity + 'ට'
    elif(tag==20):
        namedEntity = rootNamedEntity
  #  else:
   #     namedEntity = rootNamedEntity
    return namedEntity

# %%
#for index, raw in df.iterrows():
 #   print(raw)
  #  print('--')

# %%
dataFrame
# Out:
#                                                Sinhala  \
# 0                           සම්මුන්කුඩ්ඩි කුලන්තයුම්මා
# 1                                       ඉලන්කෝ තනුරාජ්
# 2                                     කතිරාමන් ඥානම්මා
# 3                            රන්හොටි බණ්ඩාරලාගේ දසනායක
# 4                              මල්ලවගේ නිශාදි පූර්නිමා
# 5                 මුතුතන්ත්‍රිගේ සුරේන්ද්‍ර කුමාර කුරේ
# 6                            උයනහේවාගේ හංසිනි ප්‍රසානි
# 7            ජයනෙත්ති කෝරාලලාගේ හිරන්ත සම්පත් ජයනෙත්ති
# 8                                     වීරයියා ජයකුමාර්
# 9                            ලෙච්චිමන් ලක්ෂිකා මධුමාලි
# 10                    විතාරමලාගේ තරිදු රසාංජන කරුණාසේන
# 11                                නෙළුව ලියනගේ ධම්මිකා
# 12                         වේලාපුර මහවඩුගේ දොන් ඇන්ටනි
# 13                        දලදාවත්තගේ දුලාන්ජය සඳකැළුම්
# 14                            නිරංජලා ලක්මාලි වගආරච්ච්
# 15                                   පරතාපයලාගේ නිලන්ත
# 16                     ගල්කැටියේ ගෙදර උපුල් ‍ප්‍රියන්ත
# 17                දිප්පිටිගල මනන්නලාගේ සංජීව සමන්කුමාර
# 18                            මල්ලිකා ගෙදර හේරත් බණ්ඩා
# 19                             පරණවිතානගේ රමේෂ් මධුරංග
# 20               හේවාවසම් පටුවත බඩතුරුගේ තිසරු මධුෂාන්
# 21                                   ජුවන්වඩු චුල්ලපාල
# 22                                       කනපති අලගම්මා
# 23                              හාමිදුලෙබ්බේ මීරසායිබු
# 24                           දන්දුන්නගේ දිනුෂා ලක්මාලි
# 25    වීරසූරිය දවූන්ඩ පණ්ඩිත ගෙදර එරංග සුපුන් වීරසූරිය
# 26                        අබ්දුල් හමිඳු මුහම්මදු හබීර්
# 27                                 අබුබක්කර් සෙයිනම්බු
# 28                          මීරා ලෙබ්බේ මුහයිදීන් බාවා
# 29                            සින්නලෙබ්බේ සෙයිතුන්බීවී
# ..                                                 ...
# 970                              මීගහපලගේ සචේන්ද රමේෂ්
# 971                                  අලගු ක්‍රිෂ්ණවේනි
# 972          කුරුනැකගේ අනුශාන්ගීකා රමෝදී නිමේෂා සිල්වා
# 973             වීරතුංග ආරච්චිගේ ලයාන් දක්ෂිත ධර්මසිරි
# 974         මාරසිංහ ආරච්චිලාගේ නිලානි ප්‍රදීපා මාරසිංහ
# 975                          නිවංකා මේව් ටානියා පීරිස්
# 976                   මොහමඩ් සාදීකීන් මුහම්මද් තව්හීඩ්
# 977                             කමල් අනුරාධ ලියනආරච්චි
# 978                            මාසිලාමනී ඇන්ටන් ජෝර්ජ්
# 979             කැකුලන්දර මුදියාන්සේලාගේ තරිඳු ලක්මාල්
# 980                   වික්‍රම ආරච්චිගේ ලෙස්ලි සේනාරත්න
# 981                             මාලිම්බඩගේ අජිත් කුමාර
# 982                            වෙඩික්කාරගේ සුරංග සංජීව
# 983                 කාරියප්පෙරුම රළලාගේ නෙල්කා මධුහංසි
# 984  වෙල්ලක්කට්ටු මුදියන්සේලාගේ සිතාරා ශාෂිණී සෙනරත...
# 985                       ඇලපාත මුදලිගේ නිෂාධි ලක්ෂිකා
# 986                                    ගෝපාලසාමි සරෝජා
# 987  පොන්නාවිල විදානේලාගේ දෝන උපේක්ෂා ජයනි අනුරිකා ...
# 988                    මොලගොඩ දිසානායකලගේ කසුන් චතුරංග
# 989     රන්දෙනි පතිරෙන්නැහැලාගේ රොහාන් නිශාන්ත රන්දෙනි
# 990                            ලක්ෂමන් නිශාන්ත පීටර්ස්
# 991                           දෙල්ගම්මන උලපොනලා රණසිංහ
# 992                          අබ්දුල් අසීස් සාජිදා භානු
# 993                                  දේව චමින්ද සුරසේන
# 994                     ගොන්සාලුවා වසම් ශානිකා ලක්මාලි
# 995                          රාජේන්ද්‍රන් වික්නේෂ්වරම්
# 996    බොව්තුරාගොඩ කන්කානම්ගේ චිත්‍රා ලංකා අබේගුණවර්ධන
# 997                        මොහමඩ් මුර්ෂිද් ෆාතිමා නුහා
# 998                             රපායිදීන් මොහමඩ් ෆයාස්
# 999                          මොහමඩ් නසාර් මොහමඩ් ෆවාස්
#
#                                                  Tamil
# 0                          சம்மூன்குட்டி குழந்தையும்மா
# 1                                       இளங்கோ தனுராஜ்
# 2                                     கதிராமன் ஞானம்மா
# 3                            ரன்ஹோட்டி பண்டாறகே தசநாயக
# 4                              மல்லவகே நிஷாதி பூர்னிமா
# 5                 முத்துதந்திரிகே சுரேந்திர குமார குரே
# 6                            உயனஹேவாகே ஹன்சினி பிரசானி
# 7            ஜயநெத்தி கோராலலாகே ஹிரன்த சம்பத் ஜயநெத்தி
# 8                                      வீரையா ஜயகுமார்
# 9                            லெச்சிமன் லக்ஷிகா மதுமாலி
# 10                 விதாரமலாகே தரிந்து ரசாஞ்ஜன கருணாசேன
# 11                                நெலுவ லியனகே தம்மிகா
# 12                         வேலாபுர மஹவடுகே டொன் அன்ரனி
# 13                       தலதாவத்தகே துலஞ்ஜய சந்தகெலும்
# 14                           நிரஞ்ஜலா லக்மாலி வகஆரச்சி
# 15                                     பரதபயலகே நிலந்த
# 16                       கல்கெடியெ கெதர உபுல் பிரியந்த
# 17               திப்பிடிகல மனன்தலாகே சன்ஜீவ சமன்குமார
# 18                            மல்லிகா கெதர ஹேரத் பண்டா
# 19                            பரணவிதானகே ரமேஷ் மதுரங்க
# 20               ஹேவாவசம் படுவத படதுருகே திசரு மதுஷான்
# 21                                   ஜுவன்வடு ஸுல்லபால
# 22                                       கணபதி அழகம்மா
# 23                             ஹாமிது லெப்வைமீராசாய்பு
# 24                           தந்துன்னகே தினுஷா லக்மாலி
# 25   வீரசூரிய தவுந்த பண்டித கெதர எரங்க சுபுன் வீரசூரிய
# 26                        அப்துல் ஹமீது முகம்மது ஹபீர்
# 27                                 அபூபக்கர் செயினம்பு
# 28                           மீரா லெப்பே முஹம்மது பாவா
# 29                            சின்னலெவ்வை செய்தூன்பீபீ
# ..                                                 ...
# 970                              மீகஹபலகே சசேந்த ரமேஷ்
# 971                                   அழகு கிருஷ்ணவேணி
# 972           குருனேககே அனுஷாங்கிக ரமோதி நிமேஷா சில்வா
# 973            வீரதுங்க ஆரச்சிகே லயான் தக்ஸித தர்மசிரி
# 974        மாரசிங்க ஆரச்சிலாகே நிலானி பிரதீபா மாரசிங்க
# 975                          நிவன்கா மேவ் டானிய பீரிஸ்
# 976                 முஹம்மட் சாதிகீன் முகம்மத் தவ்ஹீத்
# 977                             கமல் அனுராத லியனாரச்சி
# 978                              மாசிலாமணி அன்டன் ஜோச்
# 979               ககுலந்தர முதியசெலாகே தரிந்து லக்மால்
# 980                  விக்கிரம ஆரச்சிகே லெஸ்லி சேனாரத்ன
# 981                             மாலிம்படகே அஜித் குமார
# 982                          வெடிக்காரகே சுரங்க சன்ஜீவ
# 983               காரியப்பெரும ராலலாகே நெல்கா மதுஹன்சி
# 984  வெல்லக்கட்டு முதியன்சேலாகே சித்தாரா ஷாஸினி சென...
# 985                     எலபாத்த முதலிகே நிஷாதி லக்ஸிகா
# 986                                    கோபாலசாமி சரோஜா
# 987  பொன்னாவில விதானேலாகே தோன உபேக்ஷா ஜயனி அனுரிகா ...
# 988                  மொலகொட திசானாயக்க கசுன் சத்துரங்க
# 989      ரந்தெனி பதிரன்னெஹெலாகே ரொஹான் நிஷாந்த ரந்தெனி
# 990                           லக்ஷ்மன் நிஷாந்த பீடர்ஸ்
# 991                          தெல்கம்மன உலபொனலா ரணசிங்க
# 992                          அப்துல் அசீஸ் சாஜிதா பானு
# 993                                  தேவ சமிந்த சுரசேன
# 994                     கொன்சாலுவா வசம் ஷானிகா லக்மாலி
# 995                          இராஜேந்திரன் விக்னேஷ்வரம்
# 996     பௌதுராகொடா கங்கானம்கே சித்ரா லங்கா அபேகுணவர்தன
# 997                    முஹம்மது முர்ஷித் பாத்திமா நுஹா
# 998                             ரபாய்தீன் மொஹமட் பயாஸ்
# 999                          மொகமட் நசார் மொகமட் பவாஸ்
#
# [1000 rows x 2 columns]

# %%
#print(addMorpologyTamil('உபேசிங்ஹ ஜயவர்தனகே சுபுன் குமார', 4))

# %%
sinhalaVariations = []
tamilVariations = []
mixedVariations = []
for index, raw in dataFrame.iterrows():
    sinhalaBuffer = [raw['Sinhala']]
    tamilBuffer = [raw['Tamil']]
    mixedBuffer = []
    for tag in range(1, 14):
        if(tag == 13):
            tag = 20
        sinhalaMorpology = addMorpologySinhala(raw['Sinhala'], tag)
        tamilMorpology = addMorpologyTamil(raw['Tamil'], tag)
   #     mixedBuffer.append(sinhalaMorpology)
    #    mixedBuffer.append(tamilMorpology)
        sinhalaBuffer.append(sinhalaMorpology)
        tamilBuffer.append(tamilMorpology)
    #print(sinhalaBuffer)
    #print(tamilBuffer)
 #   mixedVariations
    sinhalaVariations.extend(sinhalaBuffer)
    tamilVariations.extend(tamilBuffer)

# %%
print(len(sinhalaVariations))
print(len(tamilVariations))
# Out:
# 14000
# 14000

# %%
sinhalaSeries = pd.Series(sinhalaVariations, name="Sinhala")
tamilSeries = pd.Series(tamilVariations, name="Tamil")

# %%
data = pd.DataFrame({'Sinhala':sinhalaSeries, 'Tamil':tamilSeries})

# %%
data.head()
# Out:
#                           Sinhala                                Tamil
# 0      සම්මුන්කුඩ්ඩි කුලන්තයුම්මා          சம்மூன்குட்டி குழந்தையும்மா
# 1    සම්මුන්කුඩ්ඩි කුලන්තයුම්මාගේ        சம்மூன்குட்டி குழந்தையும்மின்
# 2  සම්මුන්කුඩ්ඩි කුලන්තයුම්මාගෙන්        சம்மூன்குட்டி குழந்தையும்மில்
# 3  සම්මුන්කුඩ්ඩි කුලන්තයුම්මා සිට  சம்மூன்குட்டி குழந்தையும்மிலிருந்து
# 4    සම්මුන්කුඩ්ඩි කුලන්තයුම්මාගේ      சம்மூன்குட்டி குழந்தையும்மவினது

# %%
#sinhalaSeries.to_frame()
#tamilSeries.to_frame()

# %%
#data = pd.DataFrame(columns=['Sinhala', 'Tamil'])
#data.append()

# %%
#df1 = pd.DataFrame(data, columns = ['Sinhala', 'Tamil'])
export_excel = data.to_excel('../Corpus/Morpologies/Morpologies.xlsx', index = None, header=True)
