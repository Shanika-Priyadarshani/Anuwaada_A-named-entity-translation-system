# %%
def formatDate(inputDate, token):
    splittedList = []
    splitter = ""
    returnDate = ""
    if(token == 1 or token == 2):
        splittedList = inputDate.split("/")
        splitter = "/"
    elif(token == 3 or token == 4):
        splittedList = inputDate.split(".")
        splitter = "."
    else:
        splittedList = inputDate.split("-")
        splitter = "-"
    print(splittedList)
    if(token%2 == 0):
        returnDate = splittedList[2] + splitter + splittedList[1] + splitter + splittedList[0]
    else:
        returnDate = splittedList[0] + splitter + splittedList[1] + splitter + splittedList[2]
    return returnDate

# %%
def formatter(inputList):
    inputData = inputList[0]
    token = inputList[1]
    returnData = ""
    if(token >=1 and token <= 6):
        returnData = formatDate(inputData, token)
    elif(token == 7 or token == 8):
        returnData = inputData
    elif(token == 9):
        returnData = "පෙ.ව."
    elif(token == 10):
        returnData = "ප.ව."
    elif(token == 11):
        returnData = "ජනවාරි"
    elif(token == 12):
        returnData = "පෙබරවාරි"
    elif(token == 13):
        returnData = "මාර්තු"
    elif(token == 14):
        returnData = "අප්‍රේල්"
    elif(token == 15):
        returnData = "මැයි"
    elif(token == 16):
        returnData = "ජූනි"
    elif(token == 17):
        returnData = "ජූලි"
    elif(token == 18):
        returnData = "අගෝස්තු"
    elif(token == 19):
        returnData = "සැප්තැම්බර්"
    elif(token == 20):
        returnData = "ඔක්තෝබර්"
    elif(token == 21):
        returnData = "නොවැම්බර්"
    elif(token == 22):
        returnData = "දෙසැම්බර්"
    elif(token == 23):
        returnData = "ජන."
    elif(token == 24):
        returnData = "පෙබ."
    elif(token == 25):
        returnData = "මාර්තු."
    elif(token == 26):
        returnData = "අප්."
    elif(token == 27):
        returnData = "මැයි."
    elif(token == 28):
        returnData = "ජූනි."
    elif(token == 29):
        returnData = "ජූලි."
    elif(token == 30):
        returnData = "අගෝ."
    elif(token == 31):
        returnData = "සැප්."
    elif(token == 32):
        returnData = "ඔක්."
    elif(token == 33):
        returnData = "නොවැ."
    elif(token == 34):
        returnData = "දෙසැ."
    elif(token == 35):
        returnData = "කාර්තුව"
    elif(token == 36):
        returnData = "ඉරිදා"
    elif(token == 37):
        returnData = "සඳුදා"
    elif(token == 38):
        returnData = "අඟහරුවාදා"
    elif(token == 39):
        returnData = "බදාදා"
    elif(token == 40):
        returnData = "බ්‍රහස්පතින්දා"
    elif(token == 41):
        returnData = "සිකුරාදා"
    elif(token == 42):
        returnData = "සෙනසුරාදා"
    elif(token == 43):
        returnData = "ඉරිදා"
    elif(token == 44):
        returnData = "සඳුදා"
    elif(token == 45):
        returnData = "අඟහ"
    elif(token == 46):
        returnData = "බදාදා"
    elif(token == 47):
        returnData = "බ්‍රහස්"
    elif(token == 48):
        returnData = "සිකු"
    elif(token == 49):
        returnData = "සෙන"
    elif(token == 50):
        returnData = "මැදියම"
    elif(token == 51):
        returnData = "දහවල්"
    elif(token == 52):
        returnData = "පාන්දර"
    elif(token == 53):
        returnData = "දවල්"
    elif(token == 54):
        returnData = "හවස"
    elif(token == 55):
        returnData = "රෑ"
    elif(token == 56):
        returnData = "පොදු යුගයට පෙර"
    elif(token == 57):
        returnData = "පොදු යුගය"
    elif(token == 58):
        returnData = "ක්‍රි.පූ"
    elif(token == 59):
        returnData = "පො.පෙ"
    elif(token == 60):
        returnData = "ක්‍රි.ව"
    elif(token == 61):
        returnData = "පො.යු"
#         -------------
#     elif(token == ):
#         returnData = ""
#     elif(token == ):
#         returnData = ""
#     elif(token == ):
#         returnData = ""
#     elif(token == ):
#         returnData = ""
#     elif(token == ):
#         returnData = ""
#     elif(token == ):
#         returnData = ""
#     elif(token == ):
#         returnData = ""
#     elif(token == ):
#         returnData = ""
#     elif(token == ):
#         returnData = ""
#     elif(token == ):
#         returnData = ""
#     elif(token == ):
#         returnData = ""
#     elif(token == ):
#         returnData = ""
    else:
        returnData = inputData
    return returnData

# %%
print(formatter(['20:16', 9]))
# Out:
# පෙ.ව.
